# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('E:\\Desktop\\DS\\DS\\project\\final\\Baltimore_City_Employee_Salaries_2011.csv')
df = df.dropna()
df['HireDate'] = pd.to_datetime(df['HireDate'])
df['HireDate'] = df['HireDate'].dt.year
df['Experience'] = df['HireDate'].sub(2011, axis=0)
df['Experience'] = df['Experience'].abs()
df = df[(df.HireDate >= 1972) & (df.Experience <= 2011)]
df.drop_duplicates(inplace = True)
df1 = df.copy()
df1 = df1.drop(['Name', 'AgencyID', 'GrossPay'], axis=1)
df1['AnnualSalary'] = df1['AnnualSalary'].dropna().apply(lambda time: (time[1:]))
df1.columns
## Start of the dataset year = 2012
df = pd.read_csv('E:\\Desktop\\DS\\DS\\project\\final\\Baltimore_City_Employee_Salaries_FY2012.csv')
df = df.dropna()
df['HireDate'] = pd.to_datetime(df['HireDate'])
df['HireDate'] = df['HireDate'].dt.year
df['Experience'] = df['HireDate'].sub(2012, axis=0)
df['Experience'] = df['Experience'].abs()
df = df[(df.Experience >= 0) & (df.Experience <= 40)]
df = df[(df.HireDate >= 1972) & (df.Experience <= 2012)]
df.drop_duplicates(inplace = True)
df.rename(columns={'name': 'Name'}, inplace=True)
df['AnnualSalary'] = df['AnnualSalary'].dropna().apply(lambda time: (time[1:]))
df2 = df.copy()
df2.columns
df2 = df2.drop(['Name', 'AgencyID', 'GrossPay'], axis=1)
## Start for the year dataset - 2013
df = pd.read_csv('E:\\Desktop\\DS\\DS\\project\\final\\Baltimore_City_Employee_Salaries_FY2013.csv')
df = df.dropna()
df['HIRE_DT'] = pd.to_datetime(df['HIRE_DT'])
df['DESCR'] = df['DESCR'].replace(['COMP-Audits (001)', 'COMP-Audits (002)'], ['COMP-Audits', 'COMP-Audits'])
df['DESCR'].replace(regex=True,inplace=True,to_replace=r'\d',value=r'')
df['DESCR'] = df['DESCR'].str.replace(r'(',"")
df['DESCR'] = df['DESCR'].str.replace(r')',"")
df['HIRE_DT'] = df['HIRE_DT'].dt.year
df['Experience'] = df['HIRE_DT'].sub(2013, axis=0)
df['Experience'] = df['Experience'].abs()
df = df[(df.Experience >= 0) & (df.Experience <= 40)]
df = df[(df.HIRE_DT >= 1972) & (df.Experience <= 2013)]
df.rename(columns={'NAME': 'Name','JOBTITLE': 'JobTitle','DESCR': 'Agency','HIRE_DT': 'HireDate','ANNUAL_RT': 'AnnualSalary'}, inplace=True)
df3 = df.copy()
df3.columns
df3 = df3.drop(['Name', 'DEPTID', 'Gross'], axis=1)
df3['AnnualSalary'] = df3['AnnualSalary'].dropna().apply(lambda time: (time[1:]))
sorted(df3['Agency'].unique())
df = pd.read_csv('E:\\Desktop\\DS\\DS\\project\\final\\Baltimore_City_Employee_Salaries_FY2014.csv')
df = df.dropna()
df['HireDate'] = pd.to_datetime(df['HireDate'])
df['HireDate'] = df['HireDate'].dt.year
df['Experience'] = df['HireDate'].sub(2014, axis=0)
df['Experience'] = df['Experience'].abs()
df = df[(df.Experience >= 0) & (df.Experience <= 40)]
df = df[(df.HireDate >= 1972) & (df.Experience <= 2014)]
df.rename(columns={' Name' :'Name'},inplace=True)
df4 = df.copy()
df4.columns
df4 = df4.drop(['Name', 'AgencyID', 'GrossPay'], axis=1)
df4['AnnualSalary'] = df4['AnnualSalary'].dropna().apply(lambda time: (time[1:]))
frames = [df1,df2,df3,df4]
result = pd.concat(frames)
result.columns
result.head(1)
sorted(result['Agency'].unique())
len(result['Agency'].unique())
result['Agency'] = result['Agency'].map(lambda x: x.strip())
sorted(result['Agency'].unique())
result['Agency'] = result['Agency'].replace(['COMP-Communication Ser', 
"COMP-Comptroller's O",
"Civil Rights & Wage Enfor",
'DPW-Solid Waste (wkly)',
'DPW-Solid Waste wkly',
'HLTH-Health Dept Locatio',
'HLTH-Health Dept Location',
'HLTH-Health Dept. Locatio',
'HLTH-Health Dept. Location',
'HLTH-Heatlh',
'HLTH-Heatlh Dept.',
'HLTH-Heatlh Dept. Locatio',
'HLTH-Heatlh Dept. Location',
'HLTH-Heatlh Dept. Locatio',
'HLTH-Heatlh Dept. Location',
'Mayors Office',
'Municipal & Zoning Appeals',
'Municipal & Zoning Appeals 001',
'R&P-Parks (wkly)',
'R&P-Parks wkly',
'R&P-Recreation (part-ti',
'R&P-Recreation part-time',
'TRANS-Cross Guard-S',
'TRANS-Cross Guard-Summer',
'TRANS-Highways (wkly)',
'TRANS-Highways wkly',
'Youth Cust A'],
['COMP-Communication Services',
"COMP-Comptroller's Office",
"Civil Rights & Wage Enforce",
'DPW-Solid Waste',
'DPW-Solid Waste',
'HLTH-Health Department',
'HLTH-Health Department',
'HLTH-Health Department',
'HLTH-Health Department',
'HLTH-Health Department',
'HLTH-Health Department',
'HLTH-Health Department',
'HLTH-Health Department',
'HLTH-Health Department',
'HLTH-Health Department',
'Mayors Office',
'Municipal & Zoning Appeal',
'Municipal & Zoning Appeal',
'R&P-Parks',
'R&P-Parks',
'R&P-Recreation',
'R&P-Recreation',
'TRANS-Crossing Guards',
'TRANS-Crossing Guards',
'TRANS-Highways',
'TRANS-Highways',
'Youth Cust'])

### Considering X = Jobtitle,Agency,Experience and Y = Salary
# result = result.dropna()
# result2 = result.copy()
# X = result2
# X.drop(['HireDate'],axis=1,inplace=True)
# X['JobTitle'] = X['JobTitle'].astype('category').cat.codes
# X['Agency'] = X['Agency'].astype('category').cat.codes
# X = pd.concat([X['JobTitle'], X['Agency'], X['Experience']], axis=1)
# Y = result2['AnnualSalary']
# X_new = X[:10000]
# Y_new = Y[:10000]
# print ('about to start exec')
# from sklearn import preprocessing

# Logistic regression :
# from sklearn.linear_model import LogisticRegression
# model = LogisticRegression()
# model.fit(X_new, Y_new)
# accuracy = model.score(X_new, Y_new) * 100
# print ('accuracy of logistic linear regression : %f' % accuracy)
# End of logistic regression

#  Support vector regression
# from sklearn.svm import SVR
# svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.01)
# svr_rbf.fit(X_new, Y_new)
# accuracy = svr_rbf.score(X_new, Y_new) * 100
# print ('accuracy of support vector regression : %f' % accuracy)
# Support vector regression end
# Considering X = Jobtitle,Agency,Experience and Y = Salary

## Considering X = Jobtitle and Y = Salary
# result = result.dropna()
# result2 = result.copy()
# X = result2
# X.drop(['HireDate'],axis=1,inplace=True)
# X.drop(['Agency'],axis=1,inplace=True)
# X.drop(['Experience'],axis=1,inplace=True)
# X['JobTitle'] = X['JobTitle'].astype('category').cat.codes
# X = pd.concat([X['JobTitle']], axis=1)
# Y = result2['AnnualSalary']
# X_new = X[:10000]
# Y_new = Y[:10000]
# ## Support vector regression
# from sklearn.svm import SVR
# svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.01)
# svr_rbf.fit(X_new, Y_new)
# accuracy = svr_rbf.score(X_new, Y_new) * 100
# print ('accuracy of support vector regression : %f' % accuracy)
#Support vector regression end
# Considering X = Jobtitle and Y = Salary



# ## Considering X = Agency and Y = Salary
# result = result.dropna()
# result2 = result.copy()
# X = result2
# X.drop(['HireDate'],axis=1,inplace=True)
# X.drop(['JobTitle'],axis=1,inplace=True)
# X.drop(['Experience'],axis=1,inplace=True)
# X['Agency'] = X['Agency'].astype('category').cat.codes
# X = pd.concat([X['Agency']], axis=1)
# Y = result2['AnnualSalary']
# X_new = X[:10000]
# Y_new = Y[:10000]
# ## Support vector regression
# from sklearn.svm import SVR
# svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.01)
# svr_rbf.fit(X_new, Y_new)
# accuracy = svr_rbf.score(X_new, Y_new) * 100
# print ('accuracy of support vector regression : %f' % accuracy)
#Support vector regression end
# Considering X = Jobtitle and Y = Salary



## Considering X = Experience and Y = Salary
# result = result.dropna()
# result2 = result.copy()
# X = result2
# X.drop(['HireDate'],axis=1,inplace=True)
# X.drop(['JobTitle'],axis=1,inplace=True)
# X.drop(['Agency'],axis=1,inplace=True)
# X['Agency'] = X['Experience'].astype('category').cat.codes
# X = pd.concat([X['Experience']], axis=1)
# Y = result2['AnnualSalary']
# X_new = X[:10000]
# Y_new = Y[:10000]
# ## Support vector regression
# from sklearn.svm import SVR
# svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.01)
# svr_rbf.fit(X_new, Y_new)
# accuracy = svr_rbf.score(X_new, Y_new) * 100
# print ('accuracy of support vector regression : %f' % accuracy)
#Support vector regression end
# Considering X = Jobtitle and Y = Salary



# plt.scatter(X_new, Y_new, color='darkorange', label='data')
# plt.hold('on')
# plt.plot(X_new, Y_new, color='navy',label='RBF model')
# plt.show()

# In[ ]:
# X_new = X
# Y_new = Y
# len(X_new)
#X_new = pd.concat([X_new['Experience']], axis=1)
#X = pd.concat([pd.get_dummies(result1['Agency'], prefix = 'Agency_'), result1['Experience']], axis=1)
# X_new.columns
# le = preprocessing.LabelEncoder()


# # In[ ]:

# ##dt = DecisionTreeClassifier()
# X_test = df5.copy()
# X_test['JobTitle'] = X_test['JobTitle'].astype('category').cat.codes
# X_test['Agency'] = X_test['Agency'].astype('category').cat.codes
# X_test['Agency'] = X_test['Agency'].astype('category').cat.codes
# X_test.drop(['AnnualSalary'],axis=1,inplace=True)
# Y_test = df5['AnnualSalary']


# # In[ ]:

# X_test.head(2)


# # In[ ]:

# ##Y_test.drop(['JobTitle', 'Agency', 'Experience'],axis=1,inplace=True)
# ##X_test.drop(['AnnualSalary'],axis=1,inplace=True)


# # In[ ]:

# model = LogisticRegression(penalty='l2',C=1)


# # In[ ]:




# # In[ ]:

# model.fit(X,Y)


# # In[ ]:

# print"Logistic regression is %2.2f" % accuracy_score(Y_test,model.predict(X_test))


# # In[ ]:

# Y.head(2)


# # In[ ]:

# X.head(2)


# # In[ ]:

# Y.shape()


# # In[ ]:

result = result.dropna()
result2 = result.copy()
X = result2
X.columns
# Out:
# Index(['JobTitle', 'Agency', 'HireDate', 'AnnualSalary', 'Experience'], dtype='object')

# %%
result.columns
# Out:
# Index(['JobTitle', 'Agency', 'HireDate', 'AnnualSalary', 'Experience'], dtype='object')

# %%
sorted(X['Agency'].unique())
# Out:
# ['COMP-Audits',
#  'COMP-Communication Services',
#  "COMP-Comptroller's Office",
#  'COMP-Real Estate',
#  'Circuit Court',
#  'City Council',
#  'Civil Rights & Wage Enforce',
#  'Community Relations',
#  'Council Services',
#  'DPW-Administration',
#  'DPW-Solid Waste',
#  'DPW-Water & Waste Water',
#  'ERS/EOS Admin',
#  'Elections',
#  'Enoch Pratt Free Library',
#  'FIN-Acct & Payroll',
#  'FIN-Admin & Budgets',
#  'FIN-Collections',
#  'FIN-Purchasing',
#  'FIN-Risk Management Oper',
#  'FIN-Treasury Mgt',
#  'FPR Admin',
#  'Fire Academy Recruits',
#  'Fire Department',
#  'Fire Department MIL',
#  'General Services',
#  'HLTH-Emergency Medical Team',
#  'HLTH-Health Department',
#  'HLTH-Health Department MIL',
#  'HR-Human Resources',
#  'HR-Test Monitor',
#  'Housing & Community Dev',
#  'Law Department',
#  'Legislative Reference',
#  'Liquor License Board',
#  'M-R Cable & Comm',
#  'M-R Convention Center',
#  'M-R Environmental Cntrl',
#  'M-R Human Services',
#  'M-R Info Technology',
#  'M-R Labor Commissioner',
#  "Mayor's Office",
#  'Mayors Office',
#  'Municipal & Zoning Appeal',
#  'OED-Employment Dev',
#  "Orphan's Court",
#  'Planning Department',
#  'Police Department',
#  'Police Department MIL',
#  'R&P-Administration',
#  'R&P-Parks',
#  'R&P-Recreation',
#  "Sheriff's Office",
#  'Special City Services',
#  'States Attorneys Office',
#  'TANF Cust',
#  'TRANS-Crossing Guards',
#  'TRANS-Highways',
#  'TRANS-Towing',
#  'TRANS-Traffic',
#  'Wage Commissioner',
#  'War Memorial Commission',
#  'Youth Cust',
#  'Youth Summer',
#  'Youth Temp Adult']

# %%
X['Agency'] = X['Agency'].replace(['TRANS-Crossing Guards','TRANS-Highways','TRANS-Towing','TRANS-Traffic'], ['TRANS','TRANS','TRANS','TRANS'])

# %%
X['Agency'] = X['Agency'].replace(['COMP-Audits',
 'COMP-Communication Services',
 "COMP-Comptroller's Office",
 'COMP-Real Estate'], ['COMP','COMP','COMP','COMP'])

# %%
X['Agency'] = X['Agency'].replace(['FIN-Acct & Payroll',
 'FIN-Admin & Budgets',
 'FIN-Collections',
 'FIN-Purchasing',
 'FIN-Risk Management Oper',
 'FIN-Treasury Mgt'],['FINANCIAL','FINANCIAL','FINANCIAL','FINANCIAL','FINANCIAL','FINANCIAL'])

# %%
X['Agency'] = X['Agency'].replace(['HLTH-Emergency Medical Team',
 'HLTH-Health Department',
 'HLTH-Health Department MIL',], ['HEALTH','HEALTH','HEALTH'])

# %%
X['Agency'] = X['Agency'].replace(['Police Department',
 'Police Department MIL'], ['Police','Police'])
Z=result.copy();
Z.dropna()
# Out:
#                              JobTitle                    Agency  HireDate  \
# 0       Facilities/Office Services II        OED-Employment Dev      1979
# 1          ASSISTANT STATE'S ATTORNEY   States Attorneys Office      2006
# 2                      EPIDEMIOLOGIST    HLTH-Health Department      2009
# 3                     EMT Firefighter     Fire Academy Recruits      2011
# 4                      POLICE OFFICER         Police Department      2007
# 5           LIQUOR BOARD INSPECTOR II      Liquor License Board      1995
# 6                      OFFICE ASST II  Enoch Pratt Free Library      2009
# 7         SOCIAL SERVICES COORDINATOR    HLTH-Health Department      2008
# 8                          TYPIST III   Housing & Community Dev      1986
# 9                        911 OPERATOR         Police Department      2004
# 10                   NETWORK ENGINEER            TRANS-Highways      2006
# 12             POLICE COMMAND STAFF I         Police Department      1981
# 13                  OFFICE SUPERVISOR             TRANS-Traffic      1973
# 14                            LABORER           DPW-Solid Waste      1994
# 15              FIREFIGHTER/PARAMEDIC           Fire Department      2006
# 16        CLERICAL ASSISTANT I COURTS             Circuit Court      2008
# 17                            LABORER           DPW-Solid Waste      2000
# 18                ACCOUNTING ASST III   DPW-Water & Waste Water      2007
# 19                  HOUSING INSPECTOR   Housing & Community Dev      1997
# 20       COLLECTIONS REPRESENTATIVE I           FIN-Collections      2002
# 21                     STOREKEEPER II            TRANS-Highways      1996
# 22               MAINTENANCE MECHANIC     M-R Convention Center      1996
# 23                     CROSSING GUARD     TRANS-Crossing Guards      2004
# 24      COMMUNITY HEALTH NURSE II (10    HLTH-Health Department      2003
# 25                     POLICE OFFICER         Police Department      2007
# 26               POLICE OFFICER (EID)         Police Department      2000
# 27                     SERV ASST LBRY  Enoch Pratt Free Library      1992
# 28            FIRE PUMP OPERATOR, ALS           Fire Department      2002
# 29                      Paramedic CRT           Fire Department      2005
# 30             LABORER CREW LEADER II            TRANS-Highways      2001
# ...                               ...                       ...       ...
# 18948      ANIMAL ENFORCEMENT OFFICER    HLTH-Health Department      2013
# 18949               EXECUTIVE LEVEL I            TRANS-Highways      2006
# 18950                  POLICE OFFICER         Police Department      2009
# 18951          POLICE OFFICER TRAINEE         Police Department      2014
# 18953                   JUDGE'S WIDOW            Orphan's Court      2002
# 18954                  POLICE OFFICER         Police Department      2011
# 18955       Fire Lieutenant EMS EMT-P           Fire Department      2001
# 18956  MECHANICAL MAINTENANCE TECH II   DPW-Water & Waste Water      1975
# 18957      RECREATION ARTS INSTRUCTOR            R&P-Recreation      2011
# 18958                  POLICE OFFICER         Police Department      2011
# 18959                   ACCOUNTANT II            TRANS-Highways      2007
# 18960    ACCOUNTING SYSTEMS ANALYST I        FIN-Acct & Payroll      2013
# 18961               LIBRARIAN SUPV II  Enoch Pratt Free Library      2005
# 18962      ASSISTANT STATE'S ATTORNEY   States Attorneys Office      2014
# 18963              COUNCIL TECHNICIAN              City Council      2006
# 18964      PUBLIC WORKS INSPECTOR III   DPW-Water & Waste Water      1996
# 18965          PROCUREMENT SUPERVISOR            FIN-Purchasing      2004
# 18966         INSTRUMENTATION TECH II   DPW-Water & Waste Water      1999
# 18967                    ENGINEER III   DPW-Water & Waste Water      1983
# 18968                  DEPUTY SHERIFF          Sheriff's Office      2008
# 18969             POLICE SERGEANT EID         Police Department      1998
# 18970                    POLICE CADET         Police Department      2014
# 18971                  POLICE OFFICER         Police Department      2013
# 18972           FIRE COMMAND STAFF II           Fire Department      1990
# 18973                MASON SUPERVISOR   DPW-Water & Waste Water      1988
# 18974             REAL ESTATE AGENT I          COMP-Real Estate      1977
# 18975                  POLICE OFFICER         Police Department      2012
# 18978          POLICE OFFICER TRAINEE         Police Department      2013
# 18979                  POLICE OFFICER         Police Department      2013
# 18980    Waste Water Tech Supv I Pump   DPW-Water & Waste Water      1979
#
#       AnnualSalary  Experience
# 0         50845.00          32
# 1         56595.00           5
# 2         56500.00           2
# 3         33476.00           0
# 4         50919.00           4
# 5         43278.00          16
# 6         26388.00           2
# 7         38582.00           3
# 8         34453.00          25
# 9         37677.00           7
# 10        63800.00           5
# 12        95000.00          30
# 13        45090.00          38
# 14        29723.00          17
# 15        55544.00           5
# 16        29763.00           3
# 17        28891.00          11
# 18        32853.00           4
# 19        45661.00          14
# 20        33841.00           9
# 21        35871.00          15
# 22        41706.00          15
# 23         9553.00           7
# 24        52882.00           8
# 25        58815.00           4
# 26        61990.00          11
# 27        16744.00          19
# 28        57108.00           9
# 29        60517.00           6
# 30        32683.00          10
# ...            ...         ...
# 18948     35898.00           1
# 18949     96390.00           8
# 18950     56312.00           5
# 18951     43999.00           0
# 18953       900.00          12
# 18954     44773.00           3
# 18955     73763.00          13
# 18956     43227.00          39
# 18957     20800.00           3
# 18958     52976.00           3
# 18959     49900.00           7
# 18960     47600.00           1
# 18961     63400.00           9
# 18962     55000.00           0
# 18963     60275.00           8
# 18964     61157.00          18
# 18965     80900.00          10
# 18966     51517.00          15
# 18967     75700.00          31
# 18968     44020.00           6
# 18969     77564.00          16
# 18970     28711.00           0
# 18971     44104.00           1
# 18972    129587.00          24
# 18973     52171.00          26
# 18974     58313.00          37
# 18975     44104.00           2
# 18978     43999.00           1
# 18979     44104.00           1
# 18980     53568.00          35
#
# [61228 rows x 5 columns]

# %%
##X['Agency'] = X.loc[X['Agency'].isin(["HEALTH","COMP","TRANS","Elections","Fire Department"])]
##X['Agency'] = X.loc[X['Agency'].isin(['Elections','Fire Department'])]
##Z['Agency'] = Z.loc[Z['Agency'].contains(["HEALTH","COMP","TRANS","Elections","Fire Department"])]
Z = Z[Z.Agency.isin(["HEALTH","COMP","TRANS","Elections","Fire Department"])]
##Z['Agency']= X.query('Agency in ("HEALTH","COMP","TRANS","Elections","Fire Department")')

# %%
Z['Agency'].unique()
# Out:
# array(['Fire Department', 'Elections'], dtype=object)

# %%
X[X.index.duplicated()]
# Out:
#                              JobTitle                    Agency  HireDate  \
# 0       Facilities/Office Services II        OED-Employment Dev      1979
# 1          ASSISTANT STATE'S ATTORNEY   States Attorneys Office      2006
# 2                      EPIDEMIOLOGIST                    HEALTH      2009
# 3                     EMT FIREFIGHTER           Fire Department      2011
# 4                      POLICE OFFICER                    Police      2007
# 5            RADIO DISPATCHER SHERIFF          Sheriff's Office      1999
# 6           LIQUOR BOARD INSPECTOR II      Liquor License Board      1995
# 7                        SECRETARY II  Enoch Pratt Free Library      2009
# 8                      AIDE BLUE CHIP              Youth Summer      2008
# 9         SOCIAL SERVICES COORDINATOR                    HEALTH      2008
# 10                  JTPA TRAINEE MOMR                 TANF Cust      2008
# 12                         TYPIST III   Housing & Community Dev      1986
# 13                       911 OPERATOR                    Police      2004
# 14                   NETWORK ENGINEER                     TRANS      2006
# 16             POLICE COMMAND STAFF I                    Police      1981
# 17                  OFFICE SUPERVISOR                     TRANS      1973
# 18                     AIDE BLUE CHIP              Youth Summer      2009
# 19         RECREATION ARTS INSTRUCTOR            R&P-Recreation      2007
# 20                   LABORER (Hourly)           DPW-Solid Waste      1994
# 21              FIREFIGHTER/PARAMEDIC           Fire Department      2006
# 22        CLERICAL ASSISTANT I COURTS             Circuit Court      2008
# 23                   LABORER (Hourly)           DPW-Solid Waste      2000
# 24                 EXECUTIVE LEVEL II                    HEALTH      2011
# 25                ACCOUNTING ASST III   DPW-Water & Waste Water      2007
# 26                  HOUSING INSPECTOR   Housing & Community Dev      1997
# 27                     AIDE BLUE CHIP              Youth Summer      2011
# 28                     AIDE BLUE CHIP              Youth Summer      2010
# 29     OFFICE SERVICES ASSISTANT II S   States Attorneys Office      2011
# 30         COLLECTIONS REPRESENTATIVE                 FINANCIAL      2002
# 31                     STOREKEEPER II                     TRANS      1996
# ...                               ...                       ...       ...
# 18936              EXECUTIVE LEVEL II             Mayors Office      1998
# 18940                  POLICE OFFICER                    Police      2012
# 18941                  POLICE OFFICER                    Police      2003
# 18942                  POLICE OFFICER                    Police      2003
# 18945                  POLICE OFFICER                    Police      2000
# 18948      ANIMAL ENFORCEMENT OFFICER                    HEALTH      2013
# 18949               EXECUTIVE LEVEL I                     TRANS      2006
# 18950                  POLICE OFFICER                    Police      2009
# 18951          POLICE OFFICER TRAINEE                    Police      2014
# 18953                   JUDGE'S WIDOW            Orphan's Court      2002
# 18955       Fire Lieutenant EMS EMT-P           Fire Department      2001
# 18956  MECHANICAL MAINTENANCE TECH II   DPW-Water & Waste Water      1975
# 18957      RECREATION ARTS INSTRUCTOR            R&P-Recreation      2011
# 18959                   ACCOUNTANT II                     TRANS      2007
# 18960    ACCOUNTING SYSTEMS ANALYST I                 FINANCIAL      2013
# 18961               LIBRARIAN SUPV II  Enoch Pratt Free Library      2005
# 18962      ASSISTANT STATE'S ATTORNEY   States Attorneys Office      2014
# 18963              COUNCIL TECHNICIAN              City Council      2006
# 18964      PUBLIC WORKS INSPECTOR III   DPW-Water & Waste Water      1996
# 18965          PROCUREMENT SUPERVISOR                 FINANCIAL      2004
# 18966         INSTRUMENTATION TECH II   DPW-Water & Waste Water      1999
# 18967                    ENGINEER III   DPW-Water & Waste Water      1983
# 18968                  DEPUTY SHERIFF          Sheriff's Office      2008
# 18970                    POLICE CADET                    Police      2014
# 18972           FIRE COMMAND STAFF II           Fire Department      1990
# 18973                MASON SUPERVISOR   DPW-Water & Waste Water      1988
# 18974             REAL ESTATE AGENT I                      COMP      1977
# 18978          POLICE OFFICER TRAINEE                    Police      2013
# 18979                  POLICE OFFICER                    Police      2013
# 18980    Waste Water Tech Supv I Pump   DPW-Water & Waste Water      1979
#
#       AnnualSalary  Experience
# 0         51862.00          33
# 1         64000.00           6
# 2         57900.00           3
# 3         34146.00           1
# 4         58244.00           5
# 5         41194.00          13
# 6         44143.00          17
# 7         31741.00           3
# 8         11310.00           4
# 9         39354.00           4
# 10        15080.00           4
# 12        36109.00          26
# 13        41645.00           8
# 14        63800.00           6
# 16        98000.00          31
# 17        45994.00          39
# 18        11310.00           3
# 19        24960.00           5
# 20        30368.00          18
# 21        56655.00           6
# 22        33966.00           4
# 23        29515.00          12
# 24       100000.00           1
# 25        34718.00           5
# 26        46575.00          15
# 27        11310.00           1
# 28        11310.00           2
# 29        29343.00           1
# 30        34518.00          10
# 31        36590.00          16
# ...            ...         ...
# 18936    150756.00          16
# 18940     44104.00           2
# 18941     62380.00          11
# 18942     62975.00          11
# 18945     64757.00          14
# 18948     35898.00           1
# 18949     96390.00           8
# 18950     56312.00           5
# 18951     43999.00           0
# 18953       900.00          12
# 18955     73763.00          13
# 18956     43227.00          39
# 18957     20800.00           3
# 18959     49900.00           7
# 18960     47600.00           1
# 18961     63400.00           9
# 18962     55000.00           0
# 18963     60275.00           8
# 18964     61157.00          18
# 18965     80900.00          10
# 18966     51517.00          15
# 18967     75700.00          31
# 18968     44020.00           6
# 18970     28711.00           0
# 18972    129587.00          24
# 18973     52171.00          26
# 18974     58313.00          37
# 18978     43999.00           1
# 18979     44104.00           1
# 18980     53568.00          35
#
# [42261 rows x 5 columns]

# %%
Z.columns
# Out:
# Index(['JobTitle', 'Agency', 'HireDate', 'AnnualSalary', 'Experience'], dtype='object')

# %%
Z['Agency'].value_counts()
# Out:
# Fire Department    6553
# Elections            33
# Name: Agency, dtype: int64

# %%
Z['AnnualSalary'].min()
# Out:
# '10000.00'

# %%
result['Agency'].unique()
# Out:
# array(['OED-Employment Dev', 'States Attorneys Office',
#        'HLTH-Health Department', 'Fire Academy Recruits',
#        'Police Department', 'Liquor License Board',
#        'Enoch Pratt Free Library', 'Housing & Community Dev',
#        'TRANS-Highways', 'TRANS-Traffic', 'DPW-Solid Waste',
#        'Fire Department', 'Circuit Court', 'DPW-Water & Waste Water',
#        'FIN-Collections', 'M-R Convention Center', 'TRANS-Crossing Guards',
#        "Sheriff's Office", 'FIN-Purchasing', 'COMP-Communication Services',
#        'COMP-Audits', 'R&P-Parks', 'Youth Cust', 'R&P-Recreation',
#        'General Services', 'R&P-Administration', 'Legislative Reference',
#        'HR-Human Resources', 'FIN-Admin & Budgets', 'M-R Info Technology',
#        'TRANS-Towing', 'COMP-Real Estate', 'Youth Temp Adult',
#        'Law Department', 'City Council', 'DPW-Administration', 'Elections',
#        'Community Relations', 'FIN-Acct & Payroll', 'Planning Department',
#        "COMP-Comptroller's Office", 'Mayors Office', 'ERS/EOS Admin',
#        'FPR Admin', 'M-R Environmental Cntrl', 'Council Services',
#        'TANF Cust', 'War Memorial Commission', 'HR-Test Monitor',
#        'M-R Labor Commissioner', 'HLTH-Emergency Medical Team',
#        'Special City Services', 'Municipal & Zoning Appeal',
#        "Mayor's Office", 'M-R Cable & Comm', "Orphan's Court",
#        'Wage Commissioner', 'Youth Summer', 'Police Department MIL',
#        'M-R Human Services', 'Civil Rights & Wage Enforce',
#        'Fire Department MIL', 'HLTH-Health Department MIL',
#        'FIN-Risk Management Oper', 'FIN-Treasury Mgt'], dtype=object)

# %%
Z=result.copy();
Z.dropna()
Z = Z[Z.Agency.isin(["HEALTH","COMP","TRANS","Elections","Fire Department"])]
zcopy = Z.copy();

# %%
Z['Agency'].value_counts()
# Out:
# Fire Department    6553
# Elections            33
# Name: Agency, dtype: int64

# %%
Z.columns
# Out:
# Index(['JobTitle', 'Agency', 'HireDate', 'AnnualSalary', 'Experience'], dtype='object')

# %%
Z.drop(['HireDate'],axis=1,inplace=True)

# %%
Z['JobTitle'] = Z['JobTitle'].astype('category').cat.codes
Z['Agency'] = Z['Agency'].astype('category').cat.codes
Z = pd.concat([Z['JobTitle'], Z['Agency'], Z['Experience']], axis=1)
Y = Z.copy()

# %%
Y.columns
# Out:
# Index(['JobTitle', 'Agency', 'Experience'], dtype='object')

# %%
result = result.dropna()
result2 = result.copy()
X = result
result.columns
# Out:
# Index(['JobTitle', 'Agency', 'HireDate', 'AnnualSalary', 'Experience'], dtype='object')

# %%
Z=result.copy();
Z.dropna()
Z = Z[Z.Agency.isin(["HEALTH","COMP","TRANS","Elections","Fire Department"])]
Z.drop(['HireDate'],axis=1,inplace=True)
Z['JobTitle'] = Z['JobTitle'].astype('category').cat.codes
Z['Agency'] = Z['Agency'].astype('category').cat.codes
Z = pd.concat([Z['JobTitle'], Z['Agency'], Z['Experience']], axis=1)
Z.columns
# Out:
# Index(['JobTitle', 'Agency', 'Experience'], dtype='object')

# %%
Y = result.copy()
Y = Y[Y.Agency.isin(["HEALTH","COMP","TRANS","Elections","Fire Department"])]
Y.drop(['Agency'],axis=1,inplace=True)
Y.drop(['Experience'],axis=1,inplace=True)
Y.drop(['JobTitle'],axis=1,inplace=True)
Y.drop(['HireDate'],axis=1,inplace=True)
Y = pd.concat([Y['AnnualSalary']], axis=1)
Y.columns
# Out:
# Index(['AnnualSalary'], dtype='object')

# %%
Y.columns
# Out:
# Index(['AnnualSalary'], dtype='object')

# %%
zcopy.columns
# Out:
# Index(['JobTitle', 'Agency', 'HireDate', 'AnnualSalary', 'Experience'], dtype='object')

# %%
Zuniques, z1 = np.unique(Z['Agency'], return_inverse=True)

# %%
plt.scatter(x=Z["Experience"],y=zcopy['AnnualSalary'] , marker ='o', s=50 , c= Z['Agency'])
#plt.plot()

# %%
plt.xlim(min(Z['Experience']),max(Z['Experience']))
plt.show()
